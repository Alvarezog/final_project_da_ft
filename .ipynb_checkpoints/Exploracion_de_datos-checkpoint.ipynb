# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('carpetas_completa_junio_2021.csv', low_memory=False)

# %%
data.head(2)
# Out:
#    ao_hechos mes_hechos         fecha_hechos  ao_inicio mes_inicio  \
# 0     2016.0      Enero  2016-01-31 22:16:00       2016    Febrero
# 1     2016.0      Enero  2016-01-31 20:50:00       2016    Febrero
#
#           fecha_inicio                                             delito  \
# 0  2016-02-01 00:25:44                DAÑO EN PROPIEDAD AJENA INTENCIONAL
# 1  2016-02-01 00:52:37  ROBO DE VEHICULO DE SERVICIO PARTICULAR CON VI...
#
#                                             fiscalia    agencia  \
# 0                     INVESTIGACIÓN EN BENITO JUÁREZ       BJ-2
# 1  INVESTIGACIÓN PARA LA ATENCIÓN DEL DELITO DE R...  ORIENTEII
#
#   unidad_investigacion                      categoria_delito  \
# 0               UI-3CD                DELITO DE BAJO IMPACTO
# 1               UI-3CD  ROBO DE VEHÍCULO CON Y SIN VIOLENCIA
#
#        calle_hechos calle_hechos2   colonia_hechos alcaldia_hechos  \
# 0  CALZ. DE TLALPAN     LAGO PTE.  AMÉRICAS UNIDAS   BENITO JUAREZ
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1248924 entries, 0 to 1248923
# Data columns (total 19 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   ao_hechos             1248489 non-null  float64
#  1   mes_hechos            1248489 non-null  object
#  2   fecha_hechos          1248489 non-null  object
#  3   ao_inicio             1248924 non-null  int64
#  4   mes_inicio            1248924 non-null  object
#  5   fecha_inicio          1248921 non-null  object
#  6   delito                1248924 non-null  object
#  7   fiscalia              1248922 non-null  object
#  8   agencia               1248924 non-null  object
#  9   unidad_investigacion  1248697 non-null  object
#  10  categoria_delito      1248924 non-null  object
#  11  calle_hechos          1245804 non-null  object
#  12  calle_hechos2         487246 non-null   object
#  13  colonia_hechos        1197664 non-null  object
# ...

# %%
ao = data['ao_hechos'].value_counts()

# %%
ao.iloc[:60]
# Out:
# 2018.0    253746
# 2019.0    243392
# 2017.0    227131
# 2020.0    199917
# 2016.0    194938
# 2021.0    100587
# 2015.0     15942
# 2014.0      4264
# 2013.0      2175
# 2012.0      1539
# 2011.0      1053
# 2010.0       885
# 2009.0       483
# 2008.0       464
# 2007.0       314
# 2006.0       256
# 2001.0       195
# 2005.0       192
# 2004.0       163
# 2003.0       112
# 2002.0       105
# 2000.0       104
# 1998.0        56
# 1999.0        45
# 1997.0        41
# 1992.0        32
# 1995.0        29
# 1996.0        29
# 1990.0        28
# 1993.0        25
# 1989.0        24
# 1994.0        23
# 1969.0        17
# 1991.0        16
# 1987.0        15
# 1984.0        15
# 1983.0        13
# 1986.0        12
# 1985.0         9
# 1974.0         8
# 1988.0         8
# 1982.0         7
# 1972.0         7
# 1980.0         7
# 1981.0         6
# 1976.0         6
# 1975.0         4
# 1963.0         4
# 1962.0         3
# 1955.0         3
# 1978.0         3
# 1979.0         3
# ...

# %%
data = data.sort_values('ao_hechos', ascending=False)

# %%
data.head(30)
# Out:
#          ao_hechos mes_hechos         fecha_hechos  ao_inicio mes_inicio  \
# 1248923     2021.0      Junio  2021-06-29 17:00:00       2021      Junio
# 1187113     2021.0      Marzo  2021-03-14 10:00:00       2021      Marzo
# 1187099     2021.0      Marzo  2021-03-28 19:38:00       2021      Marzo
# 1187100     2021.0      Marzo  2021-03-29 18:00:00       2021      Marzo
# 1187101     2021.0      Marzo  2021-03-29 17:30:00       2021      Marzo
# 1187102     2021.0      Marzo  2021-03-17 10:00:00       2021      Marzo
# 1187103     2021.0    Febrero  2021-02-28 17:00:00       2021      Marzo
# 1187104     2021.0      Marzo  2021-03-28 12:16:00       2021      Marzo
# 1187105     2021.0      Marzo  2021-03-28 10:00:00       2021      Marzo
# 1187106     2021.0      Marzo  2021-03-29 08:10:00       2021      Marzo
# 1187108     2021.0      Marzo  2021-03-27 13:30:00       2021      Marzo
# 1187109     2021.0      Marzo  2021-03-29 15:30:00       2021      Marzo
# ...

# %%
data_2021 = data[data['ao_hechos']==2021.0]

# %%
data_2021['mes_hechos'].unique()
# Out:
# array(['Junio', 'Marzo', 'Febrero', 'Enero', 'Abril', 'Mayo'],
#       dtype=object)

# %%
data_2021[data_2021['mes_hechos']=='Junio'].head(50)
# Out:
#          ao_hechos mes_hechos         fecha_hechos  ao_inicio mes_inicio  \
# 1248923     2021.0      Junio  2021-06-29 17:00:00       2021      Junio
# 1232336     2021.0      Junio  2021-06-06 18:00:00       2021      Junio
# 1231046     2021.0      Junio  2021-06-03 22:00:00       2021      Junio
# 1230950     2021.0      Junio  2021-06-01 07:30:00       2021      Junio
# 1230951     2021.0      Junio  2021-06-03 18:10:00       2021      Junio
# 1230952     2021.0      Junio  2021-06-03 14:00:00       2021      Junio
# 1230953     2021.0      Junio  2021-06-03 17:00:00       2021      Junio
# 1230954     2021.0      Junio  2021-06-03 14:40:00       2021      Junio
# 1230955     2021.0      Junio  2021-06-02 23:00:00       2021      Junio
# 1230956     2021.0      Junio  2021-06-03 11:15:00       2021      Junio
# 1230957     2021.0      Junio  2021-06-02 04:40:00       2021      Junio
# 1230958     2021.0      Junio  2021-06-02 19:30:00       2021      Junio
# ...

# %%
data.isnull().sum()
# Out:
# ao_hechos                   435
# mes_hechos                  435
# fecha_hechos                435
# ao_inicio                     0
# mes_inicio                    0
# fecha_inicio                  3
# delito                        0
# fiscalia                      2
# agencia                       0
# unidad_investigacion        227
# categoria_delito              0
# calle_hechos               3120
# calle_hechos2            761678
# colonia_hechos            51260
# alcaldia_hechos            3488
# competencia             1064079
# longitud                  50302
# latitud                   50302
# tempo                   1248924
# dtype: int64

# %%
data['delito'].value_counts()
# Out:
# VIOLENCIA FAMILIAR                     129056
# FRAUDE                                  76975
# ROBO DE OBJETOS                         72807
# AMENAZAS                                67458
# ROBO A NEGOCIO SIN VIOLENCIA            66809
#                                         ...
# SECUESTRO                                   1
# ASOCIACION DELICTUOSA                       1
# DESACATO                                    1
# PROCREACION ASISTIDA                        1
# CONTRA LA LEY GENERAL DE EXPLOSIVOS         1
# Name: delito, Length: 345, dtype: int64

# %%
"""
Notas sobre los datos:

    1.- Se tienen un total de 1,248,924 registros.
    2.- Los registros van desde el año 1930 (Probablemente sea error de captura) hasta el 2021.
        Esta es la distribución de los datos por año:
        2018.0    253746
        2019.0    243392
        2017.0    227131
        2020.0    199917
        2016.0    194938
        2021.0    100587
        2015.0     15942
        2014.0      4264
        2013.0      2175
        2012.0      1539
        2011.0      1053
        2010.0       885
        2009.0       483
        2008.0       464
        2007.0       314
        2006.0       256
        2001.0       195
        2005.0       192
        2004.0       163
        2003.0       112
        2002.0       105
        2000.0       104
        1998.0        56
    3.- El resto de los años que no aparecen en esta lista tienen menos de 50 registros.
    4.- 14 columnas tienen valores nulos. Varias de esas columnas tienen un número considerable de valores nulos.
        Las columnas con datos nulos más relevantes para este análisis son las de latitud y longitud (50302 cada una).
    5.- Las columnas año, mes y fecha actualmente son tipo objeto, probablemente tengan que ser convertidas a tipo fecha.
    6.- Existen 345 tipos diferentes de delitos esta columna tendrá que ser limpiada y filtrada para tener solo los delitos
        relevantes para este análisis.
    
"""
